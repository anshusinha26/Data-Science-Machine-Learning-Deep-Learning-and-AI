# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Get the data

# %%
# creata housing DataFrame
housing = pd.read_csv('housing/housing.csv')

# %%
# get the first five rows 
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# get the datatypes of the attributes/features
housing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
# get a description of the data
housing.info()

# Note: total_bedrooms = 20433, i.e, 20640 - 20433 = 207 null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# get a statistical description of the data
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# get the shape (rows X cols)
housing.shape
# Out:
# (20640, 10)

# %%
# get the total length of the data
len(housing)
# Out:
# 20640

# %%
 # ocean_proximity attribute is categorical
housing['ocean_proximity'].value_counts(ascending=False)
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
# there are 5 unique categories in ocean_proximity attibute
len(housing['ocean_proximity'].unique())
# Out:
# 5

# %%
# get a histogram plot of the whole data
housing.hist(bins=50, figsize=(20,15));

# %% [markdown]
# # 3. Create train and test set

# %%
# import train_test_split class from model_selection module
from sklearn.model_selection import train_test_split

# split the train - 80% of the data and test - 20% of the data, setting the random_state to 42 
# (every time this code cell is run, same state of train and test sets will be produced)
train, test = train_test_split(housing, test_size=0.2, random_state=42)

# %%
# get the length of the train set
len(train)
# Out:
# 16512

# %%
# get the length of test set
len(test)
# Out:
# 4128

# %%
# get a histogram plot of the housing's median_income attribute
housing['median_income'].hist();

# %%
# reduce the number of income categories and replace them with balanced income categories
housing['income_cat'] = np.ceil(housing['median_income']/1.5)
housing['income_cat'].where(housing['income_cat'] < 5, 5.0, inplace=True)

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    income_cat
# 0         5.0
# 1         5.0
# 2         5.0
# ...

# %%
# find if there exists null values in the housing dataset, sort them with largest first
housing.isna().sum().sort_values(ascending=False)
# Out:
# total_bedrooms        207
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# income_cat              0
# dtype: int64

# %% [markdown]
# ## 3.1 Stratified sampling
#
# Stratified sampling is a sampling technique used in statistics and research to ensure that the sample drawn from a population is representative of the entire population, particularly when the population exhibits certain subgroups or strata with distinct characteristics.

# %%
# import the StratifiedShuffleSplit class from the model_selection module
from sklearn.model_selection import StratifiedShuffleSplit

# initialise an instance of the StratifiedShuffleSplit class with number of splits = 1, test_size = 20% of the data
# and random_state = 42 (preserving the shuffled nature)
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# iterate over the indices generated by the split.split() method
for train_index, test_index in split.split(housing, housing['income_cat']):
    # strat_train_test includes the subset of housing DataFrame including the indices of the train_index
    strat_train_set = housing.loc[train_index]
    # strat_train_test includes the subset of housing DataFrame including the indices of the test_index
    strat_test_set = housing.loc[test_index]

# %%
# proportion of each of the category relative to the total population
housing['income_cat'].value_counts() / len(housing)
# Out:
# income_cat
# 3.0    0.350581
# 2.0    0.318847
# 4.0    0.176308
# 5.0    0.114438
# 1.0    0.039826
# Name: count, dtype: float64

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    income_cat
# 0         5.0
# 1         5.0
# 2         5.0
# ...

# %%
# remove income_cat attribuite to bring back the originality
for set in (strat_train_set, strat_test_set):
    set.drop(['income_cat'], axis=1, inplace=True)

# %% [markdown]
# # 4. Discover and visualise the data to gain insights

# %%
# make a copy of the strat_test_set
housing = strat_train_set.copy()

# %% [markdown]
# ## 4.1 Visualising geographical data

# %%
housing.plot(kind='scatter', x='longitude', y='latitude');

# %%
# visualise the places where there is high density of data points
housing.plot(kind='scatter', x='longitude', y='latitude', alpha=0.1)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# *  The radius of each circle represents the district’s population (option s), and the color represents the price (option c). We will use a predefined color map (option cmap) called jet, which ranges from blue (low values) to red (high prices)

# %%
housing.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    alpha=0.4,
    s=housing['population']/100,
    label='population',
    c='median_house_value',
    cmap=plt.get_cmap('jet'),
    colorbar=True
)

plt.legend();

# %% [markdown]
# ## 4.2 Looking for correlations

# %%
from pandas.plotting import scatter_matrix

attributes = [
    'median_house_value',
    'median_income',
    'total_rooms',
    'housing_median_age'
]

scatter_matrix(housing[attributes], figsize=(14, 10));

# %%
# the most promising attribute to predict the median house value is the median income, so let's zoom in their
# correlation scatterplot
housing.plot(
    kind='scatter',
    x='median_income',
    y='median_house_value',
    alpha=0.1
);

# %% [markdown]
# * Note: This plot reveals a few things. First, the correlation is indeed very strong; you can clearly see the upward trend and the points are not too dispersed. Second, the price cap that we noticed earlier is clearly visible as a horizontal line at `$500,000`. But this plot reveals other less obvious straight lines: a horizontal line around `$450,000`, another around `$350,000`, perhaps one around `$280,000`, and a few more below that. You may want to try removing the corresponding districts to prevent your algorithms from learning to reproduce these data quirks.

# %% [markdown]
# ## 4.3 Experimenting with attribute combinations

# %%
housing['rooms_per_household'] = housing['total_rooms']/housing['households']
housing['bedrooms_per_room'] = housing['total_bedrooms']/housing['total_rooms']
housing['population_per_household'] = housing['population']/housing['households']

# %% [markdown]
# # 5. Prepare the data for machine learning algorithms

# %% [markdown]
# ## 5.1 Data cleaning

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
#
#        population  households  median_income  median_house_value  \
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
#
#       ocean_proximity  rooms_per_household  bedrooms_per_room  \
# ...
